# %% [markdown]
# Carregar o pacote pandas

# %%
import pandas as pd

# %% [markdown]
# Carregar o dataset

# %%
df = pd.read_csv('dataset/spotify_dataclean.csv')
print(df)

# %% [markdown]
# 1. Insight de hits com maior duração

# %%
head_max_duration = df[['track_name', 'artist_name', 'track_duration_min']].sort_values(by='track_duration_min', ascending=False).head().reset_index(drop=True)
